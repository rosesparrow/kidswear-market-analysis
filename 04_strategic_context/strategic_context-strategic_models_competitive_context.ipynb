# %% [markdown]
# # Strategic Models & Competitive Context
# **Premium Teen (11–19) Loungewear / Pyjama Market – March 2026**
#
# This notebook synthesizes business/social models from the competitor set, reviews adjacent players, and positions brands relative to the £55–85 premium teen segment.
#
# ## 1. Strategic Models Identified
#
# (table is of brands analyzed)

# %%
import pandas as pd

models_data = [
    {
        "Model": "Traditional premium",
        "Brands": "D&D, Petite Plume",
        "Approach": "Editorial aesthetic, influencer UGC, likes hidden",
        "Relevance": "Quality benchmark"
    },
    {
        "Model": "Accessible premium",
        "Brands": "Roller Rabbit",
        "Approach": "Premium social + mass distribution (e.g. Target)",
        "Relevance": "Volume strategy"
    },
    {
        "Model": "Algorithm-first",
        "Brands": "White Fox",
        "Approach": "High-frequency posting, volume-led content",
        "Relevance": "Not directly comparable (global breakout)"
    },
    {
        "Model": "TikTok-native founder",
        "Brands": "Pink Palm Puff",
        "Approach": "Founder IS influencer, viral drops, no traditional marketing",
        "Relevance": "Primary reference model"
    }
]

df_models = pd.DataFrame(models_data)
df_models.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_c39a4_row0_col0, #T_c39a4_row0_col1, #T_c39a4_row0_col2, #T_c39a4_row0_col3, #T_c39a4_row1_col0, #T_c39a4_row1_col1, #T_c39a4_row1_col2, #T_c39a4_row1_col3, #T_c39a4_row2_col0, #T_c39a4_row2_col1, #T_c39a4_row2_col2, #T_c39a4_row2_col3, #T_c39a4_row3_col0, #T_c39a4_row3_col1, #T_c39a4_row3_col2, #T_c39a4_row3_col3 {
#   text-align: left;
# }
# </style>
# <table id="T_c39a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c39a4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c39a4_level0_col1" class="col_heading level0 col1" >Brands</th>
#       <th id="T_c39a4_level0_col2" class="col_heading level0 col2" >Approach</th>
#       <th id="T_c39a4_level0_col3" class="col_heading level0 col3" >Relevance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c39a4_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# ## 2. Adjacent Competitive Context
#
# Review of brands that touch the teen loungewear/pyjama space but do not directly occupy the £55–85 premium 11–19 niche.

# %%
adjacent_data = [
    {"Brand": "Pull & Bear", "Category": "Fast fashion teen", "Why it matters": "Proves 11–19 buys loungewear — but at £15–25, not premium"},
    {"Brand": "Adanola", "Category": "UK premium adult activewear", "Why it matters": "Closest UK social comp (strong IG, high revenue) — adult sizing, includes nightwear"},
    {"Brand": "Skinnydip London", "Category": "UK teen accessories/nightwear", "Why it matters": "Teen-coded brand; sells pyjama sets (~£22–£38), collab-heavy, playful aesthetic"},
    {"Brand": "Nobody's Child", "Category": "UK sustainable adult womenswear", "Why it matters": "Shows UK appetite for ethical premium — adult women only"},
    {"Brand": "Ava & Bear London", "Category": "UK premium kids sleepwear", "Why it matters": "Confirms premium kids PJ market exists — stops at ~age 10"}
]

df_adjacent = pd.DataFrame(adjacent_data)
df_adjacent.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_8cc78_row0_col0, #T_8cc78_row0_col1, #T_8cc78_row0_col2, #T_8cc78_row1_col0, #T_8cc78_row1_col1, #T_8cc78_row1_col2, #T_8cc78_row2_col0, #T_8cc78_row2_col1, #T_8cc78_row2_col2, #T_8cc78_row3_col0, #T_8cc78_row3_col1, #T_8cc78_row3_col2, #T_8cc78_row4_col0, #T_8cc78_row4_col1, #T_8cc78_row4_col2 {
#   text-align: left;
# }
# </style>
# <table id="T_8cc78">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cc78_level0_col0" class="col_heading level0 col0" >Brand</th>
#       <th id="T_8cc78_level0_col1" class="col_heading level0 col1" >Category</th>
#       <th id="T_8cc78_level0_col2" class="col_heading level0 col2" >Why it matters</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8cc78_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8cc78_row0_col0" class="data row0 col0" >Pull & Bear</td>
#       <td id="T_8cc78_row0_col1" class="data row0 col1" >Fast fashion teen</td>
# ...

# %% [markdown]
# ## 3. Positioning Map (Price vs Age Focus)
#
# Quick 2×2 to visualize where brands sit relative to the target quadrant (£55–85 + teen 11–19).

# %%
# Simple text-based 2×2 for now (you can replace with matplotlib scatter later)
print("""
          Low Price (£15–40)                  High Price (£55+)
Kids     Pull & Bear, Ava & Bear            Mini Boden, D&D (kids line)
Teen     Fast fashion fills volume          ← EMPTY → Pink Palm Puff is closest
Adult    Adanola, Nobody's Child            Skinnydip (partial overlap)
""")
# Out:
#           Low Price (£15–40)                  High Price (£55+)
# Kids     Pull & Bear, Ava & Bear            Mini Boden, D&D (kids line)
# Teen     Fast fashion fills volume          ← EMPTY → Pink Palm Puff is closest
# Adult    Adanola, Nobody's Child            Skinnydip (partial overlap)

# %% [markdown]
# ## 4. Key Synthesis & Insights
#
# - Pink Palm Puff is the standout reference model: TikTok-native, founder-led, high-engagement, cross-platform balanced.
# - No brand currently occupies the exact £55–85 premium loungewear/pyjama position for ages 11–19 on strong social channels.
# - Fast fashion fills low-price teen demand; premium brands cap at younger ages or skew adult.
#
# ## 5. The Gap in One Sentence
#
# **Fast fashion serves the 11–19 age group cheaply. Premium brands stop at age 10. The £55–85 pyjama and loungewear segment for UK teens is unoccupied on both Instagram and TikTok.**
#
# ## Next Step
#
# Proceed to `06_fmarket_opportunity`
